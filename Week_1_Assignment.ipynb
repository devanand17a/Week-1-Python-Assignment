# %% [markdown]
# # Nobel Prize Winners Dataset
# ## Importing LIbraries required
# ### Importing pandas and numpy

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\devan\Downloads\Random\SDnobel.csv")
df.head()
# Out:
#    Unnamed: 0  year    category  \
# 0           0  1901   Chemistry
# 1           1  1901  Literature
# 2           2  1901    Medicine
# 3           3  1901       Peace
# 4           4  1901       Peace
#
#                                             prize  \
# 0               The Nobel Prize in Chemistry 1901
# 1              The Nobel Prize in Literature 1901
# 2  The Nobel Prize in Physiology or Medicine 1901
# 3                      The Nobel Peace Prize 1901
# 4                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# ...

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# usa_born_winner           0
# decade                    0
# female                    0
# age                      28
# age_group                 0
# dtype: int64

# %% [markdown]
# ### Checking info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            911 non-null    int64
#  1   year                  911 non-null    int64
#  2   category              911 non-null    object
#  3   prize                 911 non-null    object
#  4   motivation            823 non-null    object
#  5   prize_share           911 non-null    object
#  6   laureate_id           911 non-null    int64
#  7   laureate_type         911 non-null    object
#  8   full_name             911 non-null    object
#  9   birth_date            883 non-null    object
#  10  birth_city            883 non-null    object
#  11  birth_country         885 non-null    object
#  12  sex                   885 non-null    object
#  13  organization_name     665 non-null    object
#  14  organization_city     667 non-null    object
# ...

# %% [markdown]
# ### Checking Statistical Summary

# %%
df.describe()
# Out:
#        Unnamed: 0         year  laureate_id       decade         age
# count  911.000000   911.000000   911.000000   911.000000  883.000000
# mean   455.000000  1969.201976   462.515917  1964.698134   59.453001
# std    263.127346    32.837978   270.236159    32.998368   12.399290
# min      0.000000  1901.000000     1.000000  1900.000000   17.000000
# 25%    227.500000  1946.000000   228.500000  1940.000000   50.000000
# 50%    455.000000  1975.000000   457.000000  1970.000000   60.000000
# 75%    682.500000  1997.000000   698.500000  1990.000000   69.000000
# max    910.000000  2016.000000   937.000000  2010.000000   90.000000

# %% [markdown]
# ### Number for rows and columns

# %%
df.shape
# Out:
# (911, 24)

# %%
len(df)
# Out:
# 911

# %% [markdown]
# ### Column Names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'category', 'prize', 'motivation', 'prize_share',
#        'laureate_id', 'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
#        'organization_country', 'death_date', 'death_city', 'death_country',
#        'usa_born_winner', 'decade', 'female', 'age', 'age_group'],
#       dtype='object')

# %% [markdown]
# ### Removing a row and checking shape

# %%
df.drop(9, inplace= True)

# %%
df.head(10)
# Out:
#     Unnamed: 0  year    category  \
# 0            0  1901   Chemistry
# 1            1  1901  Literature
# 2            2  1901    Medicine
# 3            3  1901       Peace
# 4            4  1901       Peace
# 5            5  1901     Physics
# 6            6  1902   Chemistry
# 7            7  1902  Literature
# 8            8  1902    Medicine
# 10          10  1902       Peace
#
#                                              prize  \
# 0                The Nobel Prize in Chemistry 1901
# 1               The Nobel Prize in Literature 1901
# 2   The Nobel Prize in Physiology or Medicine 1901
# 3                       The Nobel Peace Prize 1901
# 4                       The Nobel Peace Prize 1901
# 5                  The Nobel Prize in Physics 1901
# 6                The Nobel Prize in Chemistry 1902
# 7               The Nobel Prize in Literature 1902
# 8   The Nobel Prize in Physiology or Medicine 1902
# 10                      The Nobel Peace Prize 1902
#
# ...

# %%
df.shape
# Out:
# (910, 24)

# %% [markdown]
# ### Drop null values

# %%
df.drop
# Out:
# <bound method DataFrame.drop of      Unnamed: 0  year    category  \
# 0             0  1901   Chemistry
# 1             1  1901  Literature
# 2             2  1901    Medicine
# 3             3  1901       Peace
# 4             4  1901       Peace
# ..          ...   ...         ...
# 906         906  2016    Medicine
# 907         907  2016       Peace
# 908         908  2016     Physics
# 909         909  2016     Physics
# 910         910  2016     Physics
#
#                                               prize  \
# 0                 The Nobel Prize in Chemistry 1901
# 1                The Nobel Prize in Literature 1901
# 2    The Nobel Prize in Physiology or Medicine 1901
# 3                        The Nobel Peace Prize 1901
# 4                        The Nobel Peace Prize 1901
# ..                                              ...
# 906  The Nobel Prize in Physiology or Medicine 2016
# 907                      The Nobel Peace Prize 2016
# ...
